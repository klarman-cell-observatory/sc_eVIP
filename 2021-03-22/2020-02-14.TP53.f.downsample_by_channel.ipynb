# %%
# %run ./2020-02-13_utils.ipynb
# Out:
# /ahg/regevdata/users/oursu/software/anaconda3/lib/python3.6/site-packages/scanpy/api/__init__.py:6: FutureWarning:
#
# In a future version of Scanpy, `scanpy.api` will be removed.
# Simply use `import scanpy as sc` and `import scanpy.external as sce` instead.
#
#   FutureWarning,
# scanpy==1.4.5.post1 anndata==0.7.1 umap==0.3.9 numpy==1.17.2 scipy==1.4.1 pandas==0.24.2 scikit-learn==0.22 statsmodels==0.11.0 python-igraph==0.7.1 louvain==0.6.1

# %%
import copy

# %%
PROTEIN='TP53'
DATA='/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14'
results_prefix=DATA+'/'+PROTEIN+'/processed_data/A549.'+PROTEIN
SUBSAMPLED=DATA+'/'+PROTEIN+'/subsampled/A549.'+PROTEIN
os.system('mkdir -p '+DATA+'/'+PROTEIN+'/subsampled')
# Out:
# 0

# %%
adata=sc.read(results_prefix+'.raw.filt.anno.h5ad')
adata
# Out:
# WARNING: Your filename has more than two extensions: ['.TP53', '.raw', '.filt', '.anno', '.h5ad'].
# Only considering the two last: ['.anno', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.raw', '.filt', '.anno', '.h5ad'].
# Only considering the two last: ['.anno', '.h5ad'].
# AnnData object with n_obs × n_vars = 162314 × 24839
#     obs: 'batch', 'TP53_p.Al83Vl', 'TP53_R249M', 'TP53_p.Pro153Pro', 'TP53_H193Y', 'TP53_p.Asp21Asp', 'TP53_H179Y', 'TP53_Y234C', 'TP53_G245V', 'TP53_p.Thr118Thr', 'TP53_G245S', 'TP53_R110L', 'TP53_V173L', 'TP53_E285K', 'TP53_R280T', 'TP53_C277F', 'TP53_p.Tyr107His', 'TP53_P278S', 'TP53_R273L', 'TP53_V272M', 'TP53_P278L', 'TP53_p.Gln5Ar', 'TP53_G105C', 'TP53_R213Q', 'TP53_S241F', 'TP53_R248W', 'TP53_S241C', 'TP53_p.Pro295Pro', 'TP53_R158L', 'TP53_P250L', 'TP53_p.Thr312Ser', 'TP53_S127F', 'TP53_R248L', 'TP53_C141Y', 'TP53_V157F', 'TP53_p.Pro36Pro', 'TP53_C176F', 'TP53_R273H', 'TP53_Y220C', 'TP53_H193R', 'TP53_Y163C', 'TP53_R282W', 'TP53_K132N', 'TP53_R249S', 'TP53_E286K', 'TP53_H193L', 'TP53_A159P', 'TP53_G245C', 'TP53_L194R', 'TP53_p.Pro222Pro', 'TP53_V173M', 'TP53_M246V', 'TP53_G266V', 'TP53_Y205C', 'TP53_P152L', 'TP53_p.Leu344Leu', 'TP53_C238F', 'TP53_R175H', 'TP53_G266E', 'TP53_V216M', 'TP53_R337L', 'TP53_R280K', 'TP53_A159V', 'TP53_G245D', 'TP53_p.Pro58Ar', 'TP53_p.Vl31Ile', 'TP53_p.Pro47Ser', 'TP53_C135F', 'TP53_p.Pro47Pro', 'TP53_p.Thr170Thr', 'TP53_p.Vl216Vl', 'TP53_p.Ar158Ar', 'TP53_p.Ser366Al', 'TP53_R337C', 'TP53_C275Y', 'TP53_p.Pro359Pro', 'TP53_p.Glu2Glu', 'TP53_E271K', 'TP53_G244C', 'TP53_WT', 'TP53_K132R', 'TP53_V272L', 'TP53_P151S', 'TP53_H179R', 'TP53_C135Y', 'TP53_G154V', 'TP53_C176Y', 'TP53_Y236C', 'TP53_p.Pro301Pro', 'TP53_p.Glu339Lys', 'TP53_C238Y', 'TP53_I195T', 'TP53_H214R', 'TP53_G266R', 'TP53_M237I', 'TP53_C242F', 'TP53_R158H', 'TP53_p.Gly360Vl', 'TP53_C275F', 'TP53_R273C', 'mutant', 'known', 'mut.std', 'n_genes', 'percent_mito', 'n_counts'
#     var: 'n_cells'

# %%
#read in 32 channels, merge
channels=range(32)

# %%
subsampled={}

SUBS_COUNTS_LIST=[20000,2000,4000,6000,8000,10000,12000,14000,16000,18000]

for channel in channels:
    for subs_counts in SUBS_COUNTS_LIST:
    
        curr_adata=adata[adata.obs['batch']==str(channel),:].copy()
        downsampled=copy.deepcopy(curr_adata)
        print(channel,subs_counts,curr_adata.shape)
        
        median_reads=np.median(np.array(downsampled.X.sum(axis=1)))
        subsampling_factor=int(1000.0*subs_counts/median_reads)/1000
        print('subsampling factor',subsampling_factor)
        outpath=SUBSAMPLED+'.channel'+str(channel)+'.counts_per_cell'+str(subs_counts)+'.h5ad'
        print(outpath)
            
        if subsampling_factor<1:
            downsampled.X=subsample_counts(downsampled,subsampling_factor) 
        downsampled.write(outpath)
# Out:
# 0 20000 (5373, 24839)
# subsampling factor 1.005
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell20000.h5ad
# 0 2000 (5373, 24839)
# subsampling factor 0.1
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell2000.h5ad
# nonzeros 20252490
# 0 0.03155016899108887
# 5000000 54.77085733413696
# 10000000 54.686049938201904
# 15000000 54.72467803955078
# 20000000 54.78728795051575
# 1991.0
# 0 4000 (5373, 24839)
# subsampling factor 0.201
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell4000.h5ad
# nonzeros 20252490
# 0 0.03184080123901367
# 5000000 52.91270971298218
# 10000000 52.78313755989075
# 15000000 52.49497604370117
# 20000000 52.56890869140625
# 4002.0
# 0 6000 (5373, 24839)
# subsampling factor 0.301
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell6000.h5ad
# nonzeros 20252490
# 0 0.03201103210449219
# 5000000 52.80422854423523
# 10000000 53.0245463848114
# 15000000 52.716697692871094
# 20000000 52.76259207725525
# 5990.0
# 0 8000 (5373, 24839)
# subsampling factor 0.402
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell8000.h5ad
# nonzeros 20252490
# 0 0.03151845932006836
# 5000000 52.64799952507019
# 10000000 52.57448720932007
# 15000000 52.593775033950806
# 20000000 52.20897960662842
# 7992.0
# 0 10000 (5373, 24839)
# subsampling factor 0.502
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell10000.h5ad
# nonzeros 20252490
# 0 0.0308988094329834
# 5000000 52.94447684288025
# 10000000 52.8489990234375
# 15000000 52.84418177604675
# 20000000 52.74048852920532
# 10000.0
# 0 12000 (5373, 24839)
# subsampling factor 0.603
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell12000.h5ad
# nonzeros 20252490
# 0 0.03162026405334473
# 5000000 52.85571599006653
# 10000000 52.659541606903076
# 15000000 52.606117486953735
# 20000000 53.10716938972473
# 12002.0
# 0 14000 (5373, 24839)
# subsampling factor 0.703
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell14000.h5ad
# nonzeros 20252490
# 0 0.03187823295593262
# 5000000 52.708067893981934
# 10000000 52.7082314491272
# 15000000 53.018571853637695
# 20000000 52.62134528160095
# 13985.0
# 0 16000 (5373, 24839)
# subsampling factor 0.804
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell16000.h5ad
# nonzeros 20252490
# 0 0.031556129455566406
# 5000000 52.63158583641052
# 10000000 52.626891136169434
# 15000000 52.839306116104126
# 20000000 52.59959006309509
# 15998.0
# 0 18000 (5373, 24839)
# subsampling factor 0.904
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel0.counts_per_cell18000.h5ad
# nonzeros 20252490
# 0 0.031966209411621094
# 5000000 53.12985610961914
# 10000000 53.086886405944824
# 15000000 53.35947871208191
# 20000000 53.38146376609802
# 17988.0
# 1 20000 (4943, 24839)
# subsampling factor 0.992
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell20000.h5ad
# nonzeros 18834641
# 0 0.030425548553466797
# 5000000 52.1761212348938
# 10000000 52.595425605773926
# 15000000 52.39650273323059
# 19990.0
# 1 2000 (4943, 24839)
# subsampling factor 0.099
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell2000.h5ad
# nonzeros 18834641
# 0 0.029451608657836914
# 5000000 52.334223985672
# 10000000 52.41965961456299
# 15000000 52.07211112976074
# 1999.0
# 1 4000 (4943, 24839)
# subsampling factor 0.198
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell4000.h5ad
# nonzeros 18834641
# 0 0.0287020206451416
# 5000000 51.85502052307129
# 10000000 52.17270112037659
# 15000000 52.00306463241577
# 3997.0
# 1 6000 (4943, 24839)
# subsampling factor 0.297
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell6000.h5ad
# nonzeros 18834641
# 0 0.030045509338378906
# 5000000 52.74646711349487
# 10000000 52.80883598327637
# 15000000 52.60630822181702
# 5988.0
# 1 8000 (4943, 24839)
# subsampling factor 0.397
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell8000.h5ad
# nonzeros 18834641
# 0 0.029803752899169922
# 5000000 52.59692072868347
# 10000000 52.46612596511841
# 15000000 52.49671983718872
# 8011.0
# 1 10000 (4943, 24839)
# subsampling factor 0.496
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell10000.h5ad
# nonzeros 18834641
# 0 0.029824495315551758
# 5000000 52.96365427970886
# 10000000 52.785537242889404
# 15000000 52.8419873714447
# 10009.0
# 1 12000 (4943, 24839)
# subsampling factor 0.595
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell12000.h5ad
# nonzeros 18834641
# 0 0.02941441535949707
# 5000000 53.09003281593323
# 10000000 53.4566650390625
# 15000000 53.09801244735718
# 11990.0
# 1 14000 (4943, 24839)
# subsampling factor 0.694
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell14000.h5ad
# nonzeros 18834641
# 0 0.02965831756591797
# 5000000 52.92280435562134
# 10000000 53.19816994667053
# 15000000 52.60247731208801
# 13992.0
# 1 16000 (4943, 24839)
# subsampling factor 0.794
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell16000.h5ad
# nonzeros 18834641
# 0 0.03004312515258789
# 5000000 53.555304288864136
# 10000000 53.38002347946167
# 15000000 53.17205548286438
# 16006.0
# 1 18000 (4943, 24839)
# subsampling factor 0.893
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel1.counts_per_cell18000.h5ad
# nonzeros 18834641
# 0 0.028710365295410156
# 5000000 53.213770389556885
# 10000000 53.0546612739563
# 15000000 53.15708017349243
# 17998.0
# 2 20000 (5199, 24839)
# subsampling factor 1.077
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell20000.h5ad
# 2 2000 (5199, 24839)
# subsampling factor 0.107
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell2000.h5ad
# nonzeros 16832106
# 0 0.026380062103271484
# 5000000 54.45365023612976
# 10000000 54.523749589920044
# 15000000 54.12079977989197
# 1988.0
# 2 4000 (5199, 24839)
# subsampling factor 0.215
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell4000.h5ad
# nonzeros 16832106
# 0 0.02652883529663086
# 5000000 52.8995885848999
# 10000000 52.97541093826294
# 15000000 52.495060443878174
# 3998.0
# 2 6000 (5199, 24839)
# subsampling factor 0.323
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell6000.h5ad
# nonzeros 16832106
# 0 0.02640080451965332
# 5000000 51.994224548339844
# 10000000 52.11673355102539
# 15000000 52.08309364318848
# 5990.0
# 2 8000 (5199, 24839)
# subsampling factor 0.43
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell8000.h5ad
# nonzeros 16832106
# 0 0.02629399299621582
# 5000000 52.7102587223053
# 10000000 52.9924042224884
# 15000000 52.52242565155029
# 7984.0
# 2 10000 (5199, 24839)
# subsampling factor 0.538
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell10000.h5ad
# nonzeros 16832106
# 0 0.026443958282470703
# 5000000 53.356268882751465
# 10000000 53.05717396736145
# 15000000 53.01961708068848
# 9990.0
# 2 12000 (5199, 24839)
# subsampling factor 0.646
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell12000.h5ad
# nonzeros 16832106
# 0 0.025691986083984375
# 5000000 52.801586866378784
# 10000000 52.73368763923645
# 15000000 52.80907392501831
# 11994.0
# 2 14000 (5199, 24839)
# subsampling factor 0.753
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell14000.h5ad
# nonzeros 16832106
# 0 0.026467561721801758
# 5000000 52.97740721702576
# 10000000 53.1334707736969
# 5000000 53.018280267715454
# 10000000 52.42552328109741
# 15000000 52.883190870285034
# 15991.0
# 2 18000 (5199, 24839)
# subsampling factor 0.969
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel2.counts_per_cell18000.h5ad
# nonzeros 16832106
# 0 0.02708292007446289
# 5000000 52.53274416923523
# 10000000 52.727429151535034
# 15000000 52.85922408103943
# 17995.0
# 3 20000 (4944, 24839)
# subsampling factor 1.061
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell20000.h5ad
# 3 2000 (4944, 24839)
# subsampling factor 0.106
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell2000.h5ad
# nonzeros 16759557
# 0 0.026540279388427734
# 5000000 52.57546329498291
# 10000000 52.55672550201416
# 15000000 52.383397579193115
# 1998.0
# 3 4000 (4944, 24839)
# subsampling factor 0.212
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell4000.h5ad
# nonzeros 16759557
# 0 0.027011871337890625
# 5000000 52.21181392669678
# 10000000 52.304996490478516
# 15000000 52.21707034111023
# 3994.5
# 3 6000 (4944, 24839)
# subsampling factor 0.318
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell6000.h5ad
# nonzeros 16759557
# 0 0.025646686553955078
# 5000000 52.988935708999634
# 10000000 52.74318814277649
# 15000000 52.61544418334961
# 5991.5
# 3 8000 (4944, 24839)
# subsampling factor 0.424
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell8000.h5ad
# nonzeros 16759557
# 0 0.026428937911987305
# 5000000 52.51027250289917
# 10000000 52.52003574371338
# 15000000 52.50981616973877
# 7988.5
# 3 10000 (4944, 24839)
# subsampling factor 0.53
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell10000.h5ad
# nonzeros 16759557
# 0 0.026377201080322266
# 5000000 53.02265644073486
# 10000000 52.989461183547974
# 15000000 53.38370609283447
# 9986.5
# 3 12000 (4944, 24839)
# subsampling factor 0.636
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell12000.h5ad
# nonzeros 16759557
# 0 0.02687811851501465
# 5000000 53.08078074455261
# 10000000 52.99311828613281
# 15000000 53.05641579627991
# 11981.5
# 3 14000 (4944, 24839)
# subsampling factor 0.743
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell14000.h5ad
# nonzeros 16759557
# 0 0.026363849639892578
# 5000000 53.13250494003296
# 10000000 53.044588565826416
# 15000000 53.21599006652832
# 13988.5
# 3 16000 (4944, 24839)
# subsampling factor 0.849
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell16000.h5ad
# nonzeros 16759557
# 0 0.02649378776550293
# 5000000 52.444303035736084
# 10000000 52.62122988700867
# 15000000 52.78127455711365
# 15997.5
# 3 18000 (4944, 24839)
# subsampling factor 0.955
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel3.counts_per_cell18000.h5ad
# nonzeros 16759557
# 0 0.026220083236694336
# 5000000 53.17390847206116
# 10000000 53.1028208732605
# 15000000 53.09207224845886
# 17991.0
# 4 20000 (5132, 24839)
# subsampling factor 1.157
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell20000.h5ad
# 4 2000 (5132, 24839)
# subsampling factor 0.115
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell2000.h5ad
# nonzeros 16753402
# 0 0.026906967163085938
# 5000000 52.532572984695435
# 10000000 52.215086698532104
# 15000000 52.381614208221436
# 1989.5
# 4 4000 (5132, 24839)
# subsampling factor 0.231
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell4000.h5ad
# nonzeros 16753402
# 0 0.026323318481445312
# 5000000 53.18065309524536
# 10000000 53.04334211349487
# 15000000 53.02999186515808
# 3996.5
# 4 6000 (5132, 24839)
# subsampling factor 0.347
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell6000.h5ad
# nonzeros 16753402
# 0 0.026577472686767578
# 5000000 53.16663074493408
# 10000000 53.080854654312134
# 15000000 52.7781720161438
# 6004.0
# 4 8000 (5132, 24839)
# subsampling factor 0.462
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell8000.h5ad
# nonzeros 16753402
# 0 0.026367664337158203
# 5000000 52.85871744155884
# 10000000 52.718851804733276
# 15000000 52.55521082878113
# 7985.5
# 4 10000 (5132, 24839)
# subsampling factor 0.578
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell10000.h5ad
# nonzeros 16753402
# 0 0.026373863220214844
# 5000000 52.466784954071045
# 10000000 52.902517795562744
# 15000000 52.43903112411499
# 9990.5
# 4 12000 (5132, 24839)
# subsampling factor 0.694
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell12000.h5ad
# nonzeros 16753402
# 0 0.02697467803955078
# 5000000 52.6530077457428
# 10000000 52.791465044021606
# 15000000 52.81641483306885
# 12004.5
# 4 14000 (5132, 24839)
# subsampling factor 0.809
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell14000.h5ad
# nonzeros 16753402
# 0 0.0256500244140625
# 5000000 52.19244050979614
# 10000000 52.32583165168762
# 15000000 52.11479091644287
# 13986.5
# 4 16000 (5132, 24839)
# subsampling factor 0.925
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell16000.h5ad
# nonzeros 16753402
# 0 0.02666759490966797
# 5000000 52.23666167259216
# 10000000 52.10176730155945
# 15000000 52.49975299835205
# 15988.5
# 4 18000 (5132, 24839)
# subsampling factor 1.041
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel4.counts_per_cell18000.h5ad
# 5 20000 (5134, 24839)
# subsampling factor 1.068
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell20000.h5ad
# 5 2000 (5134, 24839)
# subsampling factor 0.106
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell2000.h5ad
# nonzeros 17723580
# 0 0.028514385223388672
# 5000000 52.62362194061279
# 10000000 52.84601640701294
# 15000000 52.52434253692627
# 1984.5
# 5 4000 (5134, 24839)
# subsampling factor 0.213
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell4000.h5ad
# nonzeros 17723580
# 0 0.02791619300842285
# 5000000 53.24899244308472
# 10000000 53.05514454841614
# 15000000 52.882081747055054
# 3981.5
# 5 6000 (5134, 24839)
# subsampling factor 0.32
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell6000.h5ad
# nonzeros 17723580
# 0 0.028383970260620117
# 5000000 52.726532220840454
# 10000000 52.65661263465881
# 15000000 53.01715683937073
# 5990.0
# 5 8000 (5134, 24839)
# subsampling factor 0.427
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell8000.h5ad
# nonzeros 17723580
# 0 0.027251720428466797
# 5000000 52.60604119300842
# 10000000 52.445181131362915
# 15000000 52.87713575363159
# 7983.5
# 5 10000 (5134, 24839)
# subsampling factor 0.534
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell10000.h5ad
# nonzeros 17723580
# 0 0.02852010726928711
# 5000000 52.75723147392273
# 10000000 52.788302421569824
# 15000000 52.765535831451416
# 9993.0
# 5 12000 (5134, 24839)
# subsampling factor 0.641
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell12000.h5ad
# nonzeros 17723580
# 0 0.027996301651000977
# 5000000 53.403276205062866
# 10000000 52.935218334198
# 15000000 52.837371587753296
# 11988.0
# 5 14000 (5134, 24839)
# subsampling factor 0.748
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell14000.h5ad
# nonzeros 17723580
# 0 0.028259754180908203
# 5000000 53.03375244140625
# 10000000 52.89953136444092
# 15000000 53.16290831565857
# 14002.0
# 5 16000 (5134, 24839)
# subsampling factor 0.855
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell16000.h5ad
# nonzeros 17723580
# 0 0.0282289981842041
# 5000000 53.05831527709961
# 10000000 53.16372871398926
# 15000000 53.12383508682251
# 15996.5
# 5 18000 (5134, 24839)
# subsampling factor 0.961
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel5.counts_per_cell18000.h5ad
# nonzeros 17723580
# 0 0.028823375701904297
# 5000000 52.77822542190552
# 10000000 52.49331045150757
# 15000000 52.68340182304382
# 17972.0
# 6 20000 (5449, 24839)
# subsampling factor 1.155
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel6.counts_per_cell20000.h5ad
# 6 2000 (5449, 24839)
# subsampling factor 0.115
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel6.counts_per_cell2000.h5ad
# nonzeros 18574695
# 0 0.02841973304748535
# 5000000 52.82187533378601
# 10000000 52.83735013008118
# 15000000 53.0076584815979
# 1989.0
# 6 4000 (5449, 24839)
# subsampling factor 0.231
# /ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/TP53/subsampled/A549.TP53.channel6.counts_per_cell4000.h5ad
# nonzeros 18574695
# 0 0.03027939796447754
# 5000000 52.686975717544556
