# %%
# %run ./2020-02-13_utils.ipynb
# Out:
# /ahg/regevdata/users/oursu/software/anaconda3/lib/python3.6/site-packages/scanpy/api/__init__.py:6: FutureWarning:
#
# In a future version of Scanpy, `scanpy.api` will be removed.
# Simply use `import scanpy as sc` and `import scanpy.external as sce` instead.
#
#   FutureWarning,
# scanpy==1.4.5.post1 anndata==0.7.1 umap==0.3.9 numpy==1.17.2 scipy==1.4.1 pandas==0.24.2 scikit-learn==0.22 statsmodels==0.11.0 python-igraph==0.7.1 louvain==0.6.1

# %%
PROTEIN='TP53'
DATA='/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14'
results_prefix=DATA+'/'+PROTEIN+'/processed_data/A549.'+PROTEIN
SUBSAMPLED=DATA+'/'+PROTEIN+'/subsampled/A549.'+PROTEIN
os.system('mkdir -p '+DATA+'/'+PROTEIN+'/subsampled')
# Out:
# 0

# %%
#read in data from all channels, and save into 1 large dataset
import re
import copy

#read in 32 channels of KRAS, merge
adatas={}

for counts in [20000,2000,4000,6000,8000,10000,12000,14000,16000,18000]:

    print(counts)
    
    adatas={}
    for channel in range(32):
        print(channel)
        adata=sc.read(SUBSAMPLED+'.channel'+str(channel)+'.counts_per_cell'+str(counts)+'.h5ad')
        adatas[channel]=copy.deepcopy(adata)
        
    ch1=copy.deepcopy(adatas[0])
    ch2=copy.deepcopy(adatas[1])
    ch3=copy.deepcopy(adatas[2])
    ch4=copy.deepcopy(adatas[3])
    ch5=copy.deepcopy(adatas[4])
    ch6=copy.deepcopy(adatas[5])
    ch7=copy.deepcopy(adatas[6])
    ch8=copy.deepcopy(adatas[7])
    ch9=copy.deepcopy(adatas[8])
    ch10=copy.deepcopy(adatas[9])
    ch11=copy.deepcopy(adatas[10])
    ch12=copy.deepcopy(adatas[11])
    ch13=copy.deepcopy(adatas[12])
    ch14=copy.deepcopy(adatas[13])
    ch15=copy.deepcopy(adatas[14])
    ch16=copy.deepcopy(adatas[15])
    ch17=copy.deepcopy(adatas[16])
    ch18=copy.deepcopy(adatas[17])
    ch19=copy.deepcopy(adatas[18])
    ch20=copy.deepcopy(adatas[19])
    ch21=copy.deepcopy(adatas[20])
    ch22=copy.deepcopy(adatas[21])
    ch23=copy.deepcopy(adatas[22])
    ch24=copy.deepcopy(adatas[23])
    ch25=copy.deepcopy(adatas[24])
    ch26=copy.deepcopy(adatas[25])
    ch27=copy.deepcopy(adatas[26])
    ch28=copy.deepcopy(adatas[27])
    ch29=copy.deepcopy(adatas[28])
    ch30=copy.deepcopy(adatas[29])
    ch31=copy.deepcopy(adatas[30])
    ch32=copy.deepcopy(adatas[31])

    a_concat=ch1.concatenate(ch2,ch3,ch4,ch5,ch6,ch7,ch8,ch9,ch10,ch11,ch12,ch13,ch14,ch15,ch16,ch17,ch18,ch19,ch20,ch21,ch22,ch23,ch24,ch25,ch26,ch27,ch28,ch29,ch30,ch31,ch32)
    print(a_concat)
    
    a_concat.write(SUBSAMPLED+'.channel_1to32.counts_per_cell'+str(counts)+'.h5ad')
# Out:
# 20000
# 0
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 1
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 2
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 3
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 4
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 5
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 6
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 7
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 8
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 9
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 10
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 11
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 12
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 13
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 14
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 15
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 16
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 17
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 18
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 19
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 20
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 21
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 22
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 23
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 24
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 25
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 26
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 27
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 28
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 29
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 30
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# 31
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell20000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell20000', '.h5ad'].
# AnnData object with n_obs × n_vars = 162314 × 24839
#     obs: 'TP53_A159P', 'TP53_A159V', 'TP53_C135F', 'TP53_C135Y', 'TP53_C141Y', 'TP53_C176F', 'TP53_C176Y', 'TP53_C238F', 'TP53_C238Y', 'TP53_C242F', 'TP53_C275F', 'TP53_C275Y', 'TP53_C277F', 'TP53_E271K', 'TP53_E285K', 'TP53_E286K', 'TP53_G105C', 'TP53_G154V', 'TP53_G244C', 'TP53_G245C', 'TP53_G245D', 'TP53_G245S', 'TP53_G245V', 'TP53_G266E', 'TP53_G266R', 'TP53_G266V', 'TP53_H179R', 'TP53_H179Y', 'TP53_H193L', 'TP53_H193R', 'TP53_H193Y', 'TP53_H214R', 'TP53_I195T', 'TP53_K132N', 'TP53_K132R', 'TP53_L194R', 'TP53_M237I', 'TP53_M246V', 'TP53_P151S', 'TP53_P152L', 'TP53_P250L', 'TP53_P278L', 'TP53_P278S', 'TP53_R110L', 'TP53_R158H', 'TP53_R158L', 'TP53_R175H', 'TP53_R213Q', 'TP53_R248L', 'TP53_R248W', 'TP53_R249M', 'TP53_R249S', 'TP53_R273C', 'TP53_R273H', 'TP53_R273L', 'TP53_R280K', 'TP53_R280T', 'TP53_R282W', 'TP53_R337C', 'TP53_R337L', 'TP53_S127F', 'TP53_S241C', 'TP53_S241F', 'TP53_V157F', 'TP53_V173L', 'TP53_V173M', 'TP53_V216M', 'TP53_V272L', 'TP53_V272M', 'TP53_WT', 'TP53_Y163C', 'TP53_Y205C', 'TP53_Y220C', 'TP53_Y234C', 'TP53_Y236C', 'TP53_p.Al83Vl', 'TP53_p.Ar158Ar', 'TP53_p.Asp21Asp', 'TP53_p.Gln5Ar', 'TP53_p.Glu2Glu', 'TP53_p.Glu339Lys', 'TP53_p.Gly360Vl', 'TP53_p.Leu344Leu', 'TP53_p.Pro153Pro', 'TP53_p.Pro222Pro', 'TP53_p.Pro295Pro', 'TP53_p.Pro301Pro', 'TP53_p.Pro359Pro', 'TP53_p.Pro36Pro', 'TP53_p.Pro47Pro', 'TP53_p.Pro47Ser', 'TP53_p.Pro58Ar', 'TP53_p.Ser366Al', 'TP53_p.Thr118Thr', 'TP53_p.Thr170Thr', 'TP53_p.Thr312Ser', 'TP53_p.Tyr107His', 'TP53_p.Vl216Vl', 'TP53_p.Vl31Ile', 'batch', 'known', 'mut.std', 'mutant', 'n_counts', 'n_genes', 'percent_mito'
#     var: 'n_cells'
# 2000
# 0
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 1
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 2
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 3
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 4
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 5
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 6
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 7
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 8
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 9
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 10
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 11
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 12
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 13
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 14
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 15
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 16
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 17
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 18
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 19
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 20
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 21
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 22
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 23
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 24
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 25
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 26
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 27
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 28
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 29
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 30
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# 31
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell2000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell2000', '.h5ad'].
# AnnData object with n_obs × n_vars = 162314 × 24839
#     obs: 'TP53_A159P', 'TP53_A159V', 'TP53_C135F', 'TP53_C135Y', 'TP53_C141Y', 'TP53_C176F', 'TP53_C176Y', 'TP53_C238F', 'TP53_C238Y', 'TP53_C242F', 'TP53_C275F', 'TP53_C275Y', 'TP53_C277F', 'TP53_E271K', 'TP53_E285K', 'TP53_E286K', 'TP53_G105C', 'TP53_G154V', 'TP53_G244C', 'TP53_G245C', 'TP53_G245D', 'TP53_G245S', 'TP53_G245V', 'TP53_G266E', 'TP53_G266R', 'TP53_G266V', 'TP53_H179R', 'TP53_H179Y', 'TP53_H193L', 'TP53_H193R', 'TP53_H193Y', 'TP53_H214R', 'TP53_I195T', 'TP53_K132N', 'TP53_K132R', 'TP53_L194R', 'TP53_M237I', 'TP53_M246V', 'TP53_P151S', 'TP53_P152L', 'TP53_P250L', 'TP53_P278L', 'TP53_P278S', 'TP53_R110L', 'TP53_R158H', 'TP53_R158L', 'TP53_R175H', 'TP53_R213Q', 'TP53_R248L', 'TP53_R248W', 'TP53_R249M', 'TP53_R249S', 'TP53_R273C', 'TP53_R273H', 'TP53_R273L', 'TP53_R280K', 'TP53_R280T', 'TP53_R282W', 'TP53_R337C', 'TP53_R337L', 'TP53_S127F', 'TP53_S241C', 'TP53_S241F', 'TP53_V157F', 'TP53_V173L', 'TP53_V173M', 'TP53_V216M', 'TP53_V272L', 'TP53_V272M', 'TP53_WT', 'TP53_Y163C', 'TP53_Y205C', 'TP53_Y220C', 'TP53_Y234C', 'TP53_Y236C', 'TP53_p.Al83Vl', 'TP53_p.Ar158Ar', 'TP53_p.Asp21Asp', 'TP53_p.Gln5Ar', 'TP53_p.Glu2Glu', 'TP53_p.Glu339Lys', 'TP53_p.Gly360Vl', 'TP53_p.Leu344Leu', 'TP53_p.Pro153Pro', 'TP53_p.Pro222Pro', 'TP53_p.Pro295Pro', 'TP53_p.Pro301Pro', 'TP53_p.Pro359Pro', 'TP53_p.Pro36Pro', 'TP53_p.Pro47Pro', 'TP53_p.Pro47Ser', 'TP53_p.Pro58Ar', 'TP53_p.Ser366Al', 'TP53_p.Thr118Thr', 'TP53_p.Thr170Thr', 'TP53_p.Thr312Ser', 'TP53_p.Tyr107His', 'TP53_p.Vl216Vl', 'TP53_p.Vl31Ile', 'batch', 'known', 'mut.std', 'mutant', 'n_counts', 'n_genes', 'percent_mito'
#     var: 'n_cells'
# 4000
# 0
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 1
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 2
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 3
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 4
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 5
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 6
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 7
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 8
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 9
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 10
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 11
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 12
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 13
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 14
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 15
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 16
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 17
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 18
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 19
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 20
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 21
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 22
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 23
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 24
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 25
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 26
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 27
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 28
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 29
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 30
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# 31
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell4000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell4000', '.h5ad'].
# AnnData object with n_obs × n_vars = 162314 × 24839
#     obs: 'TP53_A159P', 'TP53_A159V', 'TP53_C135F', 'TP53_C135Y', 'TP53_C141Y', 'TP53_C176F', 'TP53_C176Y', 'TP53_C238F', 'TP53_C238Y', 'TP53_C242F', 'TP53_C275F', 'TP53_C275Y', 'TP53_C277F', 'TP53_E271K', 'TP53_E285K', 'TP53_E286K', 'TP53_G105C', 'TP53_G154V', 'TP53_G244C', 'TP53_G245C', 'TP53_G245D', 'TP53_G245S', 'TP53_G245V', 'TP53_G266E', 'TP53_G266R', 'TP53_G266V', 'TP53_H179R', 'TP53_H179Y', 'TP53_H193L', 'TP53_H193R', 'TP53_H193Y', 'TP53_H214R', 'TP53_I195T', 'TP53_K132N', 'TP53_K132R', 'TP53_L194R', 'TP53_M237I', 'TP53_M246V', 'TP53_P151S', 'TP53_P152L', 'TP53_P250L', 'TP53_P278L', 'TP53_P278S', 'TP53_R110L', 'TP53_R158H', 'TP53_R158L', 'TP53_R175H', 'TP53_R213Q', 'TP53_R248L', 'TP53_R248W', 'TP53_R249M', 'TP53_R249S', 'TP53_R273C', 'TP53_R273H', 'TP53_R273L', 'TP53_R280K', 'TP53_R280T', 'TP53_R282W', 'TP53_R337C', 'TP53_R337L', 'TP53_S127F', 'TP53_S241C', 'TP53_S241F', 'TP53_V157F', 'TP53_V173L', 'TP53_V173M', 'TP53_V216M', 'TP53_V272L', 'TP53_V272M', 'TP53_WT', 'TP53_Y163C', 'TP53_Y205C', 'TP53_Y220C', 'TP53_Y234C', 'TP53_Y236C', 'TP53_p.Al83Vl', 'TP53_p.Ar158Ar', 'TP53_p.Asp21Asp', 'TP53_p.Gln5Ar', 'TP53_p.Glu2Glu', 'TP53_p.Glu339Lys', 'TP53_p.Gly360Vl', 'TP53_p.Leu344Leu', 'TP53_p.Pro153Pro', 'TP53_p.Pro222Pro', 'TP53_p.Pro295Pro', 'TP53_p.Pro301Pro', 'TP53_p.Pro359Pro', 'TP53_p.Pro36Pro', 'TP53_p.Pro47Pro', 'TP53_p.Pro47Ser', 'TP53_p.Pro58Ar', 'TP53_p.Ser366Al', 'TP53_p.Thr118Thr', 'TP53_p.Thr170Thr', 'TP53_p.Thr312Ser', 'TP53_p.Tyr107His', 'TP53_p.Vl216Vl', 'TP53_p.Vl31Ile', 'batch', 'known', 'mut.std', 'mutant', 'n_counts', 'n_genes', 'percent_mito'
#     var: 'n_cells'
# 6000
# 0
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 1
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 2
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 3
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 4
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 5
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 6
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 7
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 8
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 9
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 10
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 11
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 12
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 13
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 14
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 15
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 16
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 17
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 18
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 19
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 20
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 21
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 22
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 23
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell6000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell6000', '.h5ad'].
# 24
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell6000', '.h5ad'].
# ...
#     var: 'n_cells'
# 8000
# 0
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel0', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 1
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel1', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 2
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel2', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 3
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel3', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 4
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel4', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 5
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel5', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 6
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel6', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 7
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel7', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 8
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel8', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 9
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel9', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 10
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel10', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 11
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel11', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 12
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel12', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 13
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel13', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 14
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel14', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 15
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel15', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 16
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel16', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 17
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel17', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 18
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel18', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 19
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel19', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 20
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel20', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 21
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel21', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 22
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel22', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 23
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel23', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 24
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel24', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 25
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel25', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 26
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel26', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 27
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel27', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 28
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel28', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 29
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel29', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 30
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel30', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# 31
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.TP53', '.channel31', '.counts_per_cell8000', '.h5ad'].
# Only considering the two last: ['.counts_per_cell8000', '.h5ad'].
# AnnData object with n_obs × n_vars = 162314 × 24839
#     obs: 'TP53_A159P', 'TP53_A159V', 'TP53_C135F', 'TP53_C135Y', 'TP53_C141Y', 'TP53_C176F', 'TP53_C176Y', 'TP53_C238F', 'TP53_C238Y', 'TP53_C242F', 'TP53_C275F', 'TP53_C275Y', 'TP53_C277F', 'TP53_E271K', 'TP53_E285K', 'TP53_E286K', 'TP53_G105C', 'TP53_G154V', 'TP53_G244C', 'TP53_G245C', 'TP53_G245D', 'TP53_G245S', 'TP53_G245V', 'TP53_G266E', 'TP53_G266R', 'TP53_G266V', 'TP53_H179R', 'TP53_H179Y', 'TP53_H193L', 'TP53_H193R', 'TP53_H193Y', 'TP53_H214R', 'TP53_I195T', 'TP53_K132N', 'TP53_K132R', 'TP53_L194R', 'TP53_M237I', 'TP53_M246V', 'TP53_P151S', 'TP53_P152L', 'TP53_P250L', 'TP53_P278L', 'TP53_P278S', 'TP53_R110L', 'TP53_R158H', 'TP53_R158L', 'TP53_R175H', 'TP53_R213Q', 'TP53_R248L', 'TP53_R248W', 'TP53_R249M', 'TP53_R249S', 'TP53_R273C', 'TP53_R273H', 'TP53_R273L', 'TP53_R280K', 'TP53_R280T', 'TP53_R282W', 'TP53_R337C', 'TP53_R337L', 'TP53_S127F', 'TP53_S241C', 'TP53_S241F', 'TP53_V157F', 'TP53_V173L', 'TP53_V173M', 'TP53_V216M', 'TP53_V272L', 'TP53_V272M', 'TP53_WT', 'TP53_Y163C', 'TP53_Y205C', 'TP53_Y220C', 'TP53_Y234C', 'TP53_Y236C', 'TP53_p.Al83Vl', 'TP53_p.Ar158Ar', 'TP53_p.Asp21Asp', 'TP53_p.Gln5Ar', 'TP53_p.Glu2Glu', 'TP53_p.Glu339Lys', 'TP53_p.Gly360Vl', 'TP53_p.Leu344Leu', 'TP53_p.Pro153Pro', 'TP53_p.Pro222Pro', 'TP53_p.Pro295Pro', 'TP53_p.Pro301Pro', 'TP53_p.Pro359Pro', 'TP53_p.Pro36Pro', 'TP53_p.Pro47Pro', 'TP53_p.Pro47Ser', 'TP53_p.Pro58Ar', 'TP53_p.Ser366Al', 'TP53_p.Thr118Thr', 'TP53_p.Thr170Thr', 'TP53_p.Thr312Ser', 'TP53_p.Tyr107His', 'TP53_p.Vl216Vl', 'TP53_p.Vl31Ile', 'batch', 'known', 'mut.std', 'mutant', 'n_counts', 'n_genes', 'percent_mito'
#     var: 'n_cells'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-bce7102a39fe> in <module>
#      52     print(a_concat)
#      53
# ---> 54     a_concat.write(SUBSAMPLED+'.channel_1to32.counts_per_cell'+str(counts)+'.h5ad')
#      55
#
# /ahg/regevdata/users/oursu/software/anaconda3/lib/python3.6/site-packages/anndata/_core/anndata.py in write_h5ad(self, filename, compression, compression_opts, force_dense, as_dense)
#    1993             compression_opts=compression_opts,
#    1994             force_dense=force_dense,
# -> 1995             as_dense=as_dense,
#    1996         )
#    1997
#
# /ahg/regevdata/users/oursu/software/anaconda3/lib/python3.6/site-packages/anndata/_io/h5ad.py in write_h5ad(filepath, adata, force_dense, as_dense, dataset_kwargs, **kwargs)
#     110         write_attribute(f, "varp", adata.varp, dataset_kwargs=dataset_kwargs)
#     111         write_attribute(f, "layers", adata.layers, dataset_kwargs=dataset_kwargs)
# --> 112         write_attribute(f, "uns", adata.uns, dataset_kwargs=dataset_kwargs)
#     113     if adata.isbacked:
#     114         adata.file.open(filepath, "r+")
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /ahg/regevdata/users/oursu/software/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __exit__(self, *args)
#     440     def __exit__(self, *args):
#     441         if self.id:
# --> 442             self.close()
#     443
#     444     @with_phil
#
# /ahg/regevdata/users/oursu/software/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in close(self)
#     422                 for id_ in file_list:
#     423                     while id_.valid:
# --> 424                         h5i.dec_ref(id_)
#     425
#     426                 self.id.close()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5i.pyx in h5py.h5i.dec_ref()
#
# RuntimeError: Can't decrement id ref count (unable to close file, errno = 28, error message = 'No space left on device')
