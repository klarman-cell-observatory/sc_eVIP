# %%
bulk=t(read.table('/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/KRAS/clustering/KRAS.bulk.csv',
              sep=',',header=TRUE,row.names=1))
head(bulk)
# Out:
#            SAMD11      HES4        ISG15        ERRFI1       ENO1
# L19F       -0.06033528 -0.11667518 -0.033858825 -0.091756314  0.064259015
# A155G       0.14852172 -0.01425435 -0.023883244  0.023048896  0.005353708
# V14L       -0.17220411 -0.06722987  0.002865010 -0.004143749  0.030920535
# D57N        0.02564698  0.11507801  0.060886022  0.041554794  0.015052198
# K117R      -0.10048238 -0.17946097 -0.075132236 -0.006812525 -0.011995563
# unassigned -0.05179964  0.04159383 -0.003491598  0.022849765  0.069847643
#            EFHD2        EPHA2        UBR4         CAMK2N1      CDA          ...
# L19F       -0.053557701 -0.005466847 -0.003643651 -0.029745989 -0.030708998 ...
# A155G      -0.008820116 -0.167479694 -0.019362966  0.044834580 -0.001277659 ...
# V14L       -0.048787571  0.098613948 -0.017761361  0.010766108 -0.034592975 ...
# D57N        0.188330039  0.009050064  0.041025087 -0.004819147  0.093216181 ...
# K117R      -0.121808238 -0.020642754 -0.023070449  0.023249945 -0.097566806 ...
# unassigned -0.017601201  0.020942792  0.024545269 -0.039181873  0.089165911 ...
#            GTSE1       CTA-29F11.1 CCT8        EVA1C        CBR3
# L19F       -0.01608314 -0.04215337  0.05270177  0.090400547  0.0273718107
# A155G      -0.03644457  0.02430475  0.02565107 -0.116208196  0.0559256561
# V14L       -0.02964173  0.01101548  0.04251860  0.102592483 -0.0006333487
# D57N        0.05599263  0.03504217 -0.02255380 -0.008616619  0.0174984615
# K117R       0.03412374 -0.05700069  0.02476484  0.046516664  0.0148916887
# unassigned -0.02127174 -0.01021443  0.03484531 -0.071108155  0.0550892837
#            TFF1         PDXK        MT-ND1       MT-ATP6     MT-ND6
# L19F       -0.030408828 -0.04767608 -0.040713053 -0.02172503  0.05181227
# A155G      -0.137900382  0.17069016  0.175536066 -0.01860078  0.01587470
# V14L        0.085090630 -0.15508042 -0.051606115  0.05534701  0.00407173
# D57N       -0.096226610  0.08934776 -0.068824895  0.07030054 -0.12378663
# K117R       0.097578242 -0.16284151  0.005786836  0.04559606  0.01084374
# unassigned  0.006371447  0.02656374 -0.154785767 -0.10857200  0.03063461

# %%
length(rownames(bulk))
# Out:
# [1] 99

# %%
rownames(bulk)
# Out:
#  [1] "L19F"       "A155G"      "V14L"       "D57N"       "K117R"
#  [6] "unassigned" "T144T"      "A146T"      "D119G"      "G12F"
# [11] "G12C"       "A59T"       "A130V"      "T58I"       "G77A"
# [16] "T158A"      "K147N"      "V8V"        "G12Y"       "V14I"
# [21] "R164Q"      "G12S"       "T50I"       "C185Y"      "G60D"
# [26] "Q22H"       "Q61P"       "D33E"       "T20T"       "P110S"
# [31] "T50T"       "A146P"      "T74A"       "Q22K"       "A59G"
# [36] "A66A"       "E31K"       "D30D"       "K178K"      "G13R"
# [41] "Q61A"       "S17S"       "I163S"      "R41K"       "R149K"
# [46] "D173D"      "T144P"      "G13C"       "Y166H"      "L79I"
# [51] "K169K"      "L159S"      "K176Q"      "T158T"      "E63K"
# [56] "F141L"      "K5E"        "R68S"       "G12V"       "K147T"
# [61] "K179R"      "M111L"      "P34L"       "G75A"       "G12R"
# [66] "T127T"      "A146V"      "T20M"       "Q61H"       "Q61R"
# [71] "M170L"      "AG11TD"     "R135T"      "T50P"       "Q61L"
# [76] "G13E"       "G12I"       "V112I"      "A59E"       "K117N"
# [81] "K88K"       "C118S"      "I36M"       "AG59GV"     "L52F"
# [86] "T20R"       "WT"         "S136N"      "T74T"       "G12D"
# [91] "N26Y"       "G60V"       "G60S"       "G13V"       "Q61K"
# [96] "P34R"       "Q25H"       "G12A"       "Q99E"

# %%
scores_init=read.table('/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/KRAS/scoring/KRAS.scores_vs_K169K.csv',
                 sep=',',header=TRUE,row.names=1)
print(dim(scores_init))
rownames(scores_init)=scores_init[,'group2']
scores_init=scores_init[rownames(bulk),]
scores=data.frame(score=as.numeric(as.character(scores_init[,'HotellingT2'])))
rownames(scores)=scores_init[,'group2']
colnames(scores)='score'
head(scores)
# Out:
# [1] 99 11
#            score
# L19F        755.61292
# A155G        25.84933
# V14L       2785.11934
# D57N        480.67130
# K117R      1790.18704
# unassigned  390.21821

# %%
scores['T74T',]
# Out:
# [1] 43.87019

# %%
bulk_corr=cor(t(bulk),method='spearman')

# %%
x=bulk_corr
hc <- hclust(dist(x,method='manhattan'),method='complete')

# %%
options(repr.plot.width=20, repr.plot.height=4)

# %%
dd <- as.dendrogram(hc)
plot(dd, main = "my dendro")
# Out:
# Plot with title "my dendro"

# %%
dd.reorder <- reorder(dd, wts=scores[rownames(x),'score'],agglo.FUN = mean)
plot(dd.reorder, main = "my dendro")
# Out:
# Plot with title "my dendro"

# %%
require(dendextend)
# Out:
# Loading required package: dendextend
#
# Warning message:
# "replacing previous import 'mclust::dmvnorm' by 'mvtnorm::dmvnorm' when loading 'fpc'"
#
# ---------------------
# Welcome to dendextend version 1.8.0
# Type citation('dendextend') for how to cite the package.
#
# Type browseVignettes(package = 'dendextend') for the package vignette.
# The github page is: https://github.com/talgalili/dendextend/
#
# Suggestions and bug-reports can be submitted at: https://github.com/talgalili/dendextend/issues
# Or contact: <tal.galili@gmail.com>
#
# 	To suppress this message use:  suppressPackageStartupMessages(library(dendextend))
# ---------------------
#
#
#
# Attaching package: 'dendextend'
#
#
# The following object is masked from 'package:stats':
#
#     cutree

# %%
dend <- color_branches(dd.reorder, k=3)

# %%
plot(dend,col=c('black','lightblue','blue'))
# Out:
# plot without title

# %%
options(repr.plot.width=17, repr.plot.height=4)
d1 <- color_branches(dend, 5, col = c('black','#138D75','#BB8FCE','gold','red'))
plot(d1)
# Out:
# plot without title

# %%
options(repr.plot.width=17, repr.plot.height=4)
f_pref='/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/2020-09-15_Figures/KRAS'
pdf(paste(f_pref,'.dendrogram.pdf',sep=''),width=20,height=5)
d1 <- color_branches(dend, 5, col = c('black','#138D75','#BB8FCE','gold','red'))
print(plot(d1))
dev.off()
print(paste(f_pref,'.dendrogram.pdf',sep=''))
# Out:
# NULL
# png
#   2
# [1] "/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/2020-09-15_Figures/KRAS.dendrogram.pdf"

# %%
par('mar')
par(mar=c(1,1,1,1))
# Out:
# [1] 5.1 4.1 4.1 2.1

# %%
dev.off()
f_pref='/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/2020-09-15_Figures/KRAS'
png(paste(f_pref,'.dendrogram.png',sep=''),width=20,height=5)
d1 <- color_branches(dend, 5, col = c('black','#138D75','#BB8FCE','gold','red'))
print(plot(d1))
dev.off()
print(paste(f_pref,'.dendrogram.png',sep=''))
# Out:
# null device
#           1
# Error in plot.new(): figure margins too large
# Traceback:
#
# 1. print(plot(d1))
# 2. plot(d1)
# 3. plot.dendrogram(d1)
# 4. plot(0, xlim = xlim, ylim = ylim, type = "n", xlab = xlab, ylab = ylab,
#  .     xaxt = xaxt, yaxt = yaxt, frame.plot = frame.plot, ...)
# 5. plot.default(0, xlim = xlim, ylim = ylim, type = "n", xlab = xlab,
#  .     ylab = ylab, xaxt = xaxt, yaxt = yaxt, frame.plot = frame.plot,
#  .     ...)
# 6. plot.new()

# %%
png()
dev.off()
# Out:
# png
#   2

# %%
sorted_variants=rownames(x)[order.dendrogram(dend)]
sorted_variants_df=data.frame(variant=sorted_variants,
                              color=get_leaves_branches_col(d1))

# %%
res='/ahg/regevdata/projects/bn10_cancer_variants/bn10_oana_2018-06-22/results/2018-06-22/results/2020-02-14/KRAS/clustering/KRAS.corrL1.sorted_variants.csv'
write.table(sorted_variants_df,res,sep=',',quote=FALSE,row.names=FALSE,col.names=FALSE)
